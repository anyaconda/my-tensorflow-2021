# %%
#meta 7/20/2021 Check Infrastructure and DL Settings

#here 9/21/2021 KAGGLE KERNEL
#      same code in Kaggle kernel, with GPU accelerator

# %% [markdown]
# ## TensorFlow

# %%
#check TensorFlow, check GPU
import tensorflow as tf
#tf.get_logger().setLevel('ERROR') # Avoid TF warningsf
print(tf.__version__)

tf.config.list_physical_devices()

# %%
#import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# %%
#was
print("GPU is", "available" if
tf.config.experimental.list_physical_devices("GPU") else "NOT AVAILABLE")

# %% [markdown]
# ## PyTorch
#
# src https://forums.fast.ai/t/how-to-know-if-fastai-is-using-the-nvidia-gpu/45605/18
#
# To check the realtime GPU usage:
# watch -n 1 nvidia-smi

# %%
#check PyTorch, check GPU
import torch
torch.cuda.get_device_name(0)
